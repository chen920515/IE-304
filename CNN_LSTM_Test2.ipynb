# %% [markdown]
# <a href="https://colab.research.google.com/github/Sawnann/colab-test/blob/main/CNN_LSTM_Test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# reference code: https://www.kaggle.com/code/anitarostami/lstm-multivariate-forecasting

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Dropout, BatchNormalization, Conv1D, Flatten
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from pandas import DatetimeIndex

# %%
df_train = pd.read_csv('model2_data_train.csv')
df_train
# Out:
#           Date    co2         gdp   elec  renewanbleenergy  population    cpi  \
# 0     2004/1/1  19.69   933906.28  15020            461168       22541  82.32
# 1     2004/2/1  19.75   935798.33  14530            553953       22546  81.69
# 2     2004/3/1  19.80   937690.39  16624            598110       22551  81.63
# 3     2004/4/1  19.86   927492.46  16327            518228       22556  82.57
# 4     2004/5/1  19.91   941486.00  17047            577714       22562  82.49
# ..         ...    ...         ...    ...               ...         ...    ...
# 166  2017/11/1  22.38  1571847.00  22474            984943       23415  97.50
# 167  2017/12/1  22.37  1547388.13  20842           1023672       23419  97.35
# 168   2018/1/1  22.59  1501386.81  20687           1175567       23421  97.02
# 169   2018/2/1  22.53  1499594.67  18073           1110499       23421  97.93
# 170   2018/3/1  22.47  1497802.53  21128           1003243       23421  96.98
#
#        ipi  eport_amt  commericalvehicle  vehiclecount
# 0    40.70     421740            3546335       5203918
# 1    43.37     463788            3551410       5216924
# 2    47.90     518080            3902882       5232036
# 3    46.43     490401            1130069       5247496
# 4    47.29     551494            3899401       5261119
# ..     ...        ...                ...           ...
# 166  79.89     863180            3278243       6755022
# 167  81.46     881044            3353728       6763422
# 168  79.31     808897            3358140       6776083
# 169  63.76     647843            2855660       6779466
# 170  83.86     871498            3337141       6784083
#
# [171 rows x 11 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               171 non-null    object
#  1   co2                171 non-null    float64
#  2   gdp                171 non-null    float64
#  3   elec               171 non-null    int64
#  4   renewanbleenergy   171 non-null    int64
#  5   population         171 non-null    int64
#  6   cpi                171 non-null    float64
#  7   ipi                171 non-null    float64
#  8   eport_amt          171 non-null    int64
#  9   commericalvehicle  171 non-null    int64
#  10  vehiclecount       171 non-null    int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 14.8+ KB

# %%
df_test = pd.read_csv("model2_data_test.csv")
df_test
# Out:
#       co2         gdp   elec  renewanbleenergy  population     cpi     ipi  \
# 0   22.42  1481521.59  20920            841121       23421   97.61   75.35
# 1   22.36  1494224.67  22777            898675       23421   97.48   81.98
# 2   22.30  1506927.75  22868            947970       23422   97.88   78.81
# 3   22.24  1511015.19  24637           1054322       23425   98.22   80.02
# 4   22.18  1532660.67  24914           1052057       23426   98.16   82.51
# 5   22.12  1554306.15  24444           1277529       23426   98.32   81.11
# 6   22.06  1622754.60  23385           1255255       23427   98.39   84.60
# 7   22.00  1598527.33  21949            989363       23431   97.78   81.40
# 8   21.94  1574300.07  20776           1041007       23435   97.29   79.85
# 9   21.62  1523147.84  20847           1025434       23437   97.19   79.78
# 10  21.61  1526930.67  18362            953237       23438   98.14   62.70
# 11  21.60  1530713.49  20854           1023077       23437   97.52   77.52
# 12  21.59  1521218.53  20716           1018099       23437   98.25   77.05
# 13  21.58  1538307.33  22470           1537409       23437   98.39   80.43
# 14  21.57  1555396.14  22781           1618366       23438   98.71   78.63
# 15  21.56  1571263.34  24147           1351393       23439   98.60   83.92
# 16  21.55  1590149.67  24853           1647730       23441   98.58   85.07
# 17  21.54  1609035.99  24187           1407720       23441   98.73   81.72
# 18  21.53  1673593.95  23699           1337439       23442   98.75   84.28
# 19  21.53  1647489.67  22057           1250948       23444   98.35   83.75
# 20  21.52  1621385.39  20751           1087522       23448   98.41   86.85
# 21  21.09  1566786.44  19982           1045507       23450   99.00   78.32
# 22  21.16  1570398.33  20086           1182771       23449   97.94   77.42
# 23  21.22  1574010.23  21299           1182691       23446   97.50   87.56
# 24  21.29  1541822.06  20359           1156022       23441   97.30   81.23
# 25  21.35  1581259.00  21916           1198404       23436   97.20   82.42
# 26  21.42  1620695.94  22946           1355893       23433   97.98   85.22
# 27  21.49  1675882.05  25443           1340798       23429   98.10   88.20
# 28  21.55  1702596.00  25231           1179241       23424   98.25   90.24
# 29  21.62  1729309.95  25361           1199189       23418   98.16   93.41
# 30  21.68  1790497.80  24050           1558178       23414   98.49   91.23
# 31  21.75  1784015.33  22641           1399443       23411   98.44   92.67
# 32  21.81  1777532.86  21922           1380936       23409   98.45   98.00
# 33  22.61  1771816.08  21608           1313049       23401   98.81   95.39
# 34  22.54  1764638.33  19577           1085139       23390   99.29   80.59
# 35  22.48  1757460.59  22568           1218555       23379   98.69  102.74
# 36  22.41  1724402.30  21862           1254810       23366   99.35   94.47
# 37  22.35  1743192.33  23564           1345618       23353   99.58   98.96
# 38  22.29  1761982.37  24006           1408238       23340   99.77  102.67
# 39  22.22  1763316.20  25658           1606900       23326   99.97  102.98
# 40  22.16  1800176.67  25699           1644199       23308  100.55  104.03
# 41  22.09  1837037.13  25770           1573012       23288  100.71  105.03
# 42  22.03  1921177.10  25941           1941331       23268  101.00  102.79
# 43  21.96  1913069.67  24169           1556072       23250  101.24  104.05
# 44  21.90  1904962.23  22767           1564791       23230  101.04  106.33
#
#     eport_amt  commericalvehicle  vehiclecount
# 0      775280            3178918       6786324
# 1      860859            3360903       6793140
# 2      840814            3218312       6804823
# 3      860424            3293237       6815272
# 4      860893            3277993       6814537
# 5      906762            3198729       6820976
# 6      906308            3354676       6827292
# 7      854329            3285824       6836595
# 8      875183            3342887       6845711
# 9      835722            3325718       6853707
# 10     625792            2831303       6851210
# 11     877422            3299646       6854477
# 12     788033            3195665       6856436
# 13     852951            3344028       6865266
# 14     887814            3172150       6875047
# 15     872903            3298640       6885792
# 16     902169            3240009       6885239
# 17     877092            3146302       6890785
# 18     894738            3322593       6900192
# 19     870369            3217120       6912104
# 20     896940            3381865       6919256
# 21     751690            3167235       6920578
# 22     760749            3034752       6926232
# 23     850840            3260311       6929413
# 24     761338            3109993       6927855
# 25     808080            3187800       6935974
# 26     809338            3123614       6946528
# 27     833091            3246734       6955130
# 28     919518            3198629       6960913
# 29     903919            3163951       6970642
# 30     935880            3178766       6981794
# 31     921391            3126808       6993293
# 32     942903            3255865       6984750
# 33     974871            3163163       7000875
# 34     788187            2708559       7011023
# 35    1013086            3170482       7027428
# 36     994717            3032220       7037927
# 37    1047756            2772142       7041391
# 38    1016286            1892320       7044953
# 39    1058491            1970939       7055048
# 40    1102422            2336059       7061857
# 41    1100099            2696730       7076445
# 42    1118502            2833690       7084949
# 43    1157316            2814896       7095489
# 44    1129845            2929542       7104034

# %%
df_train.describe()
# Out:
#               co2           gdp          elec  renewanbleenergy    population  \
# count  171.000000  1.710000e+02    171.000000      1.710000e+02    171.000000
# mean    21.163567  1.211845e+06  19776.333333      7.847403e+05  23042.093567
# std      0.747451  1.750322e+05   2217.349929      2.000187e+05    263.149974
# min     19.070000  9.274925e+05  13764.000000      4.409850e+05  22541.000000
# 25%     20.825000  1.073458e+06  18372.000000      6.413470e+05  22826.500000
# 50%     21.230000  1.189670e+06  19750.000000      7.507880e+05  23057.000000
# 75%     21.540000  1.375442e+06  21353.500000      8.837315e+05  23269.500000
# max     22.590000  1.596306e+06  24380.000000      1.593690e+06  23421.000000
#
#               cpi         ipi      eport_amt  commericalvehicle  vehiclecount
# count  171.000000  171.000000     171.000000       1.710000e+02  1.710000e+02
# mean    90.695088   60.895029  694426.532164       3.424213e+06  5.984350e+06
# std      4.406518   11.383913  113496.034621       3.371025e+05  4.291320e+05
# min     81.630000   32.180000  389580.000000       1.130069e+06  5.203918e+06
# 25%     86.795000   50.670000  621860.000000       3.254310e+06  5.680490e+06
# 50%     91.040000   62.060000  731672.000000       3.380526e+06  5.839984e+06
# 75%     94.520000   69.600000  777220.000000       3.686530e+06  6.350574e+06
# max     97.930000   83.860000  881044.000000       4.181669e+06  6.784083e+06

# %%
df_train_scaled = df_train.copy()
df_test_scaled = df_test.copy()

df_train_scaled['Date'] = pd.to_datetime(df_train_scaled['Date'])
# Resetting the index
df_train_scaled.set_index('Date', inplace=True)
df_train_scaled.head()
# Out:
#               co2        gdp   elec  renewanbleenergy  population    cpi  \
# Date
# 2004-01-01  19.69  933906.28  15020            461168       22541  82.32
# 2004-02-01  19.75  935798.33  14530            553953       22546  81.69
# 2004-03-01  19.80  937690.39  16624            598110       22551  81.63
# 2004-04-01  19.86  927492.46  16327            518228       22556  82.57
# 2004-05-01  19.91  941486.00  17047            577714       22562  82.49
#
#               ipi  eport_amt  commericalvehicle  vehiclecount
# Date
# 2004-01-01  40.70     421740            3546335       5203918
# 2004-02-01  43.37     463788            3551410       5216924
# 2004-03-01  47.90     518080            3902882       5232036
# 2004-04-01  46.43     490401            1130069       5247496
# 2004-05-01  47.29     551494            3899401       5261119

# %%
df_test_scaled.head (5)
# Out:
#      co2         gdp   elec  renewanbleenergy  population    cpi    ipi  \
# 0  22.42  1481521.59  20920            841121       23421  97.61  75.35
# 1  22.36  1494224.67  22777            898675       23421  97.48  81.98
# 2  22.30  1506927.75  22868            947970       23422  97.88  78.81
# 3  22.24  1511015.19  24637           1054322       23425  98.22  80.02
# 4  22.18  1532660.67  24914           1052057       23426  98.16  82.51
#
#    eport_amt  commericalvehicle  vehiclecount
# 0     775280            3178918       6786324
# 1     860859            3360903       6793140
# 2     840814            3218312       6804823
# 3     860424            3293237       6815272
# 4     860893            3277993       6814537

# %%
scaler = MinMaxScaler()

# Define the columns to scale
# Define the columns to scale
columns = (['co2', 'gdp', 'elec', 'renewanbleenergy', "population", 'cpi',
       'ipi', 'eport_amt', 'commericalvehicle','vehiclecount'])

df_test_scaled = df_test_scaled[columns]

# Scale the selected columns to the range 0-1
df_train_scaled[columns] = scaler.fit_transform(df_train_scaled[columns])
df_test_scaled[columns] = scaler.transform(df_test_scaled[columns])

# Show the scaled data
df_train_scaled.head()
# Out:
#                  co2       gdp      elec  renewanbleenergy  population  \
# Date
# 2004-01-01  0.176136  0.009590  0.118312          0.017509    0.000000
# 2004-02-01  0.193182  0.012419  0.072155          0.098003    0.005682
# 2004-03-01  0.207386  0.015248  0.269405          0.136310    0.011364
# 2004-04-01  0.224432  0.000000  0.241428          0.067010    0.017045
# 2004-05-01  0.238636  0.020923  0.309250          0.118616    0.023864
#
#                  cpi       ipi  eport_amt  commericalvehicle  vehiclecount
# Date
# 2004-01-01  0.042331  0.164861   0.065437           0.791803      0.000000
# 2004-02-01  0.003681  0.216525   0.150994           0.793466      0.008231
# 2004-03-01  0.000000  0.304180   0.261464           0.908642      0.017794
# 2004-04-01  0.057669  0.275735   0.205144           0.000000      0.027578
# 2004-05-01  0.052761  0.292376   0.329452           0.907502      0.036199

# %%
df_test_scaled.head()
# Out:
#         co2       gdp      elec  renewanbleenergy  population       cpi  \
# 0  0.951705  0.828376  0.674077          0.347128    1.000000  0.980368
# 1  0.934659  0.847370  0.849002          0.397057    1.000000  0.972393
# 2  0.917614  0.866363  0.857573          0.439822    1.001136  0.996933
# 3  0.900568  0.872475  1.024209          0.532085    1.004545  1.017791
# 4  0.883523  0.904839  1.050301          0.530120    1.005682  1.014110
#
#         ipi  eport_amt  commericalvehicle  vehiclecount
# 0  0.835333   0.784798           0.671402      1.001418
# 1  0.963622   0.958929           0.731037      1.005732
# 2  0.902283   0.918143           0.684311      1.013125
# 3  0.925697   0.958044           0.708864      1.019738
# 4  0.973878   0.958998           0.703868      1.019273

# %%
df_train_scaled = np.array(df_train_scaled)
df_test_scaled = np.array(df_test_scaled)

X = []
y = []
n_future = 3
n_past = 3

#  Train Sets
for i in range(n_past, len(df_train_scaled) - n_future+1):
    X.append(df_train_scaled[i - n_past:i, 1:df_train_scaled.shape[1]])
    y.append(df_train_scaled[i + n_future - 1:i + n_future, 0])
X_train, y_train = np.array(X), np.array(y)

#  Test Sets

X = []
y = []
for i in range(n_past, len(df_test_scaled) - n_future+1):
    X.append(df_test_scaled[i - n_past:i, 1:df_test_scaled.shape[1]])
    y.append(df_test_scaled[i + n_future - 1:i + n_future, 0])
X_test, y_test = np.array(X), np.array(y)

print('X_train shape : {}   y_train shape : {} \n'
      'X_test shape : {}      y_test shape : {} '.format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X_train shape : (166, 3, 9)   y_train shape : (166, 1)
# X_test shape : (40, 3, 9)      y_test shape : (40, 1)

# %% [markdown]
# #  CNN-LSTM MODEL

# %%
#CNN-LSTM Model

def get_model_cnn_lstm(n_past, n_future):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_past, X_train.shape[2])))
    model.add(LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'))
    model.add(LSTM(32, return_sequences=True, activation='relu'))
    model.add(LSTM(32, return_sequences=False, activation='relu'))
    model.add(Dense(n_future))

    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# Create an instance of the model
model_cnnlstm = get_model_cnn_lstm(n_past=X_train.shape[1], n_future=y_train.shape[1])

# Print model summary to check the structure
model_cnnlstm.summary()

# Define callbacks to save the best model during training
filepath = 'CNN_LSTM.hdf5'
checkpoint_cnn_lstm = tf.keras.callbacks.ModelCheckpoint(filepath=filepath,
                                                         monitor='val_loss',
                                                         verbose=0,
                                                         save_best_only=True,
                                                         mode='min')
callbacks_cnn_lstm = [checkpoint_cnn_lstm]

# Train the model
history = model_cnnlstm.fit(X_train, y_train, epochs=500, batch_size=16, verbose=2,
                            validation_data=(X_test, y_test),
                            shuffle=False, callbacks=callbacks_cnn_lstm)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1, 64)             1792
#
#  lstm_13 (LSTM)              (None, 1, 32)             12416
#
#  lstm_14 (LSTM)              (None, 1, 32)             8320
#
#  lstm_15 (LSTM)              (None, 32)                8320
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 30,881
# Trainable params: 30,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 11/11 - 2s - loss: 0.3950 - val_loss: 0.5648 - 2s/epoch - 179ms/step
# Epoch 2/500
# 11/11 - 0s - loss: 0.3590 - val_loss: 0.4943 - 76ms/epoch - 7ms/step
# Epoch 3/500
# 11/11 - 0s - loss: 0.2957 - val_loss: 0.3176 - 63ms/epoch - 6ms/step
# Epoch 4/500
# 11/11 - 0s - loss: 0.1438 - val_loss: 0.0456 - 62ms/epoch - 6ms/step
# Epoch 5/500
# 11/11 - 0s - loss: 0.1079 - val_loss: 0.3284 - 54ms/epoch - 5ms/step
# Epoch 6/500
# 11/11 - 0s - loss: 0.0726 - val_loss: 0.0254 - 64ms/epoch - 6ms/step
# Epoch 7/500
# 11/11 - 0s - loss: 0.0723 - val_loss: 0.0146 - 63ms/epoch - 6ms/step
# Epoch 8/500
# 11/11 - 0s - loss: 0.0321 - val_loss: 0.2299 - 46ms/epoch - 4ms/step
# Epoch 9/500
# 11/11 - 0s - loss: 0.0262 - val_loss: 0.1619 - 56ms/epoch - 5ms/step
# Epoch 10/500
# 11/11 - 0s - loss: 0.0240 - val_loss: 0.0877 - 41ms/epoch - 4ms/step
# Epoch 11/500
# 11/11 - 0s - loss: 0.0241 - val_loss: 0.1250 - 56ms/epoch - 5ms/step
# Epoch 12/500
# 11/11 - 0s - loss: 0.0230 - val_loss: 0.1186 - 49ms/epoch - 4ms/step
# Epoch 13/500
# 11/11 - 0s - loss: 0.0222 - val_loss: 0.1009 - 41ms/epoch - 4ms/step
# Epoch 14/500
# 11/11 - 0s - loss: 0.0221 - val_loss: 0.1030 - 49ms/epoch - 4ms/step
# Epoch 15/500
# 11/11 - 0s - loss: 0.0217 - val_loss: 0.0967 - 56ms/epoch - 5ms/step
# Epoch 16/500
# 11/11 - 0s - loss: 0.0212 - val_loss: 0.0915 - 39ms/epoch - 4ms/step
# Epoch 17/500
# 11/11 - 0s - loss: 0.0210 - val_loss: 0.0898 - 49ms/epoch - 4ms/step
# Epoch 18/500
# 11/11 - 0s - loss: 0.0207 - val_loss: 0.0861 - 59ms/epoch - 5ms/step
# Epoch 19/500
# 11/11 - 0s - loss: 0.0204 - val_loss: 0.0842 - 45ms/epoch - 4ms/step
# Epoch 20/500
# 11/11 - 0s - loss: 0.0202 - val_loss: 0.0820 - 49ms/epoch - 4ms/step
# Epoch 21/500
# 11/11 - 0s - loss: 0.0200 - val_loss: 0.0807 - 48ms/epoch - 4ms/step
# Epoch 22/500
# 11/11 - 0s - loss: 0.0198 - val_loss: 0.0798 - 48ms/epoch - 4ms/step
# Epoch 23/500
# 11/11 - 0s - loss: 0.0195 - val_loss: 0.0787 - 49ms/epoch - 4ms/step
# Epoch 24/500
# 11/11 - 0s - loss: 0.0194 - val_loss: 0.0779 - 47ms/epoch - 4ms/step
# Epoch 25/500
# 11/11 - 0s - loss: 0.0192 - val_loss: 0.0778 - 49ms/epoch - 4ms/step
# Epoch 26/500
# 11/11 - 0s - loss: 0.0189 - val_loss: 0.0779 - 49ms/epoch - 4ms/step
# Epoch 27/500
# 11/11 - 0s - loss: 0.0187 - val_loss: 0.0770 - 57ms/epoch - 5ms/step
# Epoch 28/500
# 11/11 - 0s - loss: 0.0185 - val_loss: 0.0778 - 48ms/epoch - 4ms/step
# Epoch 29/500
# 11/11 - 0s - loss: 0.0183 - val_loss: 0.0785 - 41ms/epoch - 4ms/step
# Epoch 30/500
# 11/11 - 0s - loss: 0.0181 - val_loss: 0.0789 - 42ms/epoch - 4ms/step
# Epoch 31/500
# 11/11 - 0s - loss: 0.0179 - val_loss: 0.0789 - 43ms/epoch - 4ms/step
# Epoch 32/500
# 11/11 - 0s - loss: 0.0177 - val_loss: 0.0806 - 54ms/epoch - 5ms/step
# Epoch 33/500
# 11/11 - 0s - loss: 0.0174 - val_loss: 0.0809 - 47ms/epoch - 4ms/step
# Epoch 34/500
# 11/11 - 0s - loss: 0.0172 - val_loss: 0.0816 - 40ms/epoch - 4ms/step
# Epoch 35/500
# 11/11 - 0s - loss: 0.0170 - val_loss: 0.0832 - 58ms/epoch - 5ms/step
# Epoch 36/500
# 11/11 - 0s - loss: 0.0167 - val_loss: 0.0855 - 48ms/epoch - 4ms/step
# Epoch 37/500
# 11/11 - 0s - loss: 0.0165 - val_loss: 0.0867 - 50ms/epoch - 5ms/step
# Epoch 38/500
# 11/11 - 0s - loss: 0.0162 - val_loss: 0.0891 - 47ms/epoch - 4ms/step
# Epoch 39/500
# 11/11 - 0s - loss: 0.0160 - val_loss: 0.0910 - 40ms/epoch - 4ms/step
# Epoch 40/500
# 11/11 - 0s - loss: 0.0158 - val_loss: 0.0930 - 60ms/epoch - 5ms/step
# Epoch 41/500
# 11/11 - 0s - loss: 0.0155 - val_loss: 0.0949 - 46ms/epoch - 4ms/step
# Epoch 42/500
# 11/11 - 0s - loss: 0.0153 - val_loss: 0.0979 - 48ms/epoch - 4ms/step
# Epoch 43/500
# 11/11 - 0s - loss: 0.0151 - val_loss: 0.0997 - 49ms/epoch - 4ms/step
# Epoch 44/500
# 11/11 - 0s - loss: 0.0149 - val_loss: 0.1015 - 46ms/epoch - 4ms/step
# Epoch 45/500
# 11/11 - 0s - loss: 0.0146 - val_loss: 0.1041 - 51ms/epoch - 5ms/step
# Epoch 46/500
# 11/11 - 0s - loss: 0.0144 - val_loss: 0.1061 - 41ms/epoch - 4ms/step
# Epoch 47/500
# 11/11 - 0s - loss: 0.0143 - val_loss: 0.1086 - 60ms/epoch - 5ms/step
# Epoch 48/500
# 11/11 - 0s - loss: 0.0141 - val_loss: 0.1102 - 45ms/epoch - 4ms/step
# Epoch 49/500
# 11/11 - 0s - loss: 0.0139 - val_loss: 0.1137 - 55ms/epoch - 5ms/step
# Epoch 50/500
# 11/11 - 0s - loss: 0.0137 - val_loss: 0.1157 - 43ms/epoch - 4ms/step
# Epoch 51/500
# 11/11 - 0s - loss: 0.0135 - val_loss: 0.1189 - 58ms/epoch - 5ms/step
# Epoch 52/500
# 11/11 - 0s - loss: 0.0133 - val_loss: 0.1202 - 46ms/epoch - 4ms/step
# Epoch 53/500
# 11/11 - 0s - loss: 0.0131 - val_loss: 0.1233 - 56ms/epoch - 5ms/step
# Epoch 54/500
# 11/11 - 0s - loss: 0.0130 - val_loss: 0.1267 - 41ms/epoch - 4ms/step
# Epoch 55/500
# 11/11 - 0s - loss: 0.0128 - val_loss: 0.1281 - 57ms/epoch - 5ms/step
# Epoch 56/500
# 11/11 - 0s - loss: 0.0126 - val_loss: 0.1307 - 41ms/epoch - 4ms/step
# Epoch 57/500
# 11/11 - 0s - loss: 0.0125 - val_loss: 0.1334 - 48ms/epoch - 4ms/step
# Epoch 58/500
# 11/11 - 0s - loss: 0.0123 - val_loss: 0.1336 - 38ms/epoch - 3ms/step
# Epoch 59/500
# 11/11 - 0s - loss: 0.0121 - val_loss: 0.1370 - 56ms/epoch - 5ms/step
# Epoch 60/500
# 11/11 - 0s - loss: 0.0120 - val_loss: 0.1390 - 49ms/epoch - 4ms/step
# Epoch 61/500
# 11/11 - 0s - loss: 0.0118 - val_loss: 0.1386 - 40ms/epoch - 4ms/step
# Epoch 62/500
# 11/11 - 0s - loss: 0.0117 - val_loss: 0.1419 - 57ms/epoch - 5ms/step
# Epoch 63/500
# 11/11 - 0s - loss: 0.0115 - val_loss: 0.1447 - 41ms/epoch - 4ms/step
# Epoch 64/500
# 11/11 - 0s - loss: 0.0114 - val_loss: 0.1398 - 63ms/epoch - 6ms/step
# Epoch 65/500
# 11/11 - 0s - loss: 0.0113 - val_loss: 0.1499 - 34ms/epoch - 3ms/step
# Epoch 66/500
# 11/11 - 0s - loss: 0.0111 - val_loss: 0.1490 - 41ms/epoch - 4ms/step
# Epoch 67/500
# 11/11 - 0s - loss: 0.0110 - val_loss: 0.1428 - 56ms/epoch - 5ms/step
# Epoch 68/500
# 11/11 - 0s - loss: 0.0109 - val_loss: 0.1578 - 56ms/epoch - 5ms/step
# Epoch 69/500
# 11/11 - 0s - loss: 0.0107 - val_loss: 0.1472 - 56ms/epoch - 5ms/step
# Epoch 70/500
# 11/11 - 0s - loss: 0.0106 - val_loss: 0.1457 - 53ms/epoch - 5ms/step
# Epoch 71/500
# 11/11 - 0s - loss: 0.0105 - val_loss: 0.1650 - 52ms/epoch - 5ms/step
# Epoch 72/500
# 11/11 - 0s - loss: 0.0103 - val_loss: 0.1464 - 45ms/epoch - 4ms/step
# Epoch 73/500
# 11/11 - 0s - loss: 0.0104 - val_loss: 0.1465 - 49ms/epoch - 4ms/step
# Epoch 74/500
# 11/11 - 0s - loss: 0.0105 - val_loss: 0.1743 - 39ms/epoch - 4ms/step
# Epoch 75/500
# 11/11 - 0s - loss: 0.0103 - val_loss: 0.1418 - 59ms/epoch - 5ms/step
# Epoch 76/500
# 11/11 - 0s - loss: 0.0105 - val_loss: 0.1496 - 40ms/epoch - 4ms/step
# Epoch 77/500
# 11/11 - 0s - loss: 0.0103 - val_loss: 0.1788 - 55ms/epoch - 5ms/step
# Epoch 78/500
# 11/11 - 0s - loss: 0.0103 - val_loss: 0.1379 - 50ms/epoch - 5ms/step
# Epoch 79/500
# 11/11 - 0s - loss: 0.0110 - val_loss: 0.1447 - 47ms/epoch - 4ms/step
# Epoch 80/500
# 11/11 - 0s - loss: 0.0108 - val_loss: 0.1802 - 41ms/epoch - 4ms/step
# Epoch 81/500
# 11/11 - 0s - loss: 0.0108 - val_loss: 0.1355 - 46ms/epoch - 4ms/step
# Epoch 82/500
# 11/11 - 0s - loss: 0.0117 - val_loss: 0.1400 - 55ms/epoch - 5ms/step
# Epoch 83/500
# 11/11 - 0s - loss: 0.0108 - val_loss: 0.1453 - 55ms/epoch - 5ms/step
# Epoch 84/500
# 11/11 - 0s - loss: 0.0106 - val_loss: 0.1369 - 46ms/epoch - 4ms/step
# Epoch 85/500
# 11/11 - 0s - loss: 0.0106 - val_loss: 0.1540 - 44ms/epoch - 4ms/step
# Epoch 86/500
# 11/11 - 0s - loss: 0.0094 - val_loss: 0.1400 - 39ms/epoch - 4ms/step
# Epoch 87/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1434 - 56ms/epoch - 5ms/step
# Epoch 88/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1492 - 41ms/epoch - 4ms/step
# Epoch 89/500
# 11/11 - 0s - loss: 0.0089 - val_loss: 0.1466 - 64ms/epoch - 6ms/step
# Epoch 90/500
# 11/11 - 0s - loss: 0.0087 - val_loss: 0.1480 - 54ms/epoch - 5ms/step
# Epoch 91/500
# 11/11 - 0s - loss: 0.0086 - val_loss: 0.1572 - 49ms/epoch - 4ms/step
# Epoch 92/500
# 11/11 - 0s - loss: 0.0085 - val_loss: 0.1599 - 48ms/epoch - 4ms/step
# Epoch 93/500
# 11/11 - 0s - loss: 0.0084 - val_loss: 0.1482 - 44ms/epoch - 4ms/step
# Epoch 94/500
# 11/11 - 0s - loss: 0.0084 - val_loss: 0.1633 - 48ms/epoch - 4ms/step
# Epoch 95/500
# 11/11 - 0s - loss: 0.0084 - val_loss: 0.1591 - 56ms/epoch - 5ms/step
# Epoch 96/500
# 11/11 - 0s - loss: 0.0085 - val_loss: 0.1398 - 32ms/epoch - 3ms/step
# Epoch 97/500
# 11/11 - 0s - loss: 0.0086 - val_loss: 0.1664 - 42ms/epoch - 4ms/step
# Epoch 98/500
# 11/11 - 0s - loss: 0.0086 - val_loss: 0.1483 - 42ms/epoch - 4ms/step
# Epoch 99/500
# 11/11 - 0s - loss: 0.0095 - val_loss: 0.1376 - 58ms/epoch - 5ms/step
# Epoch 100/500
# 11/11 - 0s - loss: 0.0101 - val_loss: 0.1515 - 40ms/epoch - 4ms/step
# Epoch 101/500
# 11/11 - 0s - loss: 0.0096 - val_loss: 0.1412 - 55ms/epoch - 5ms/step
# Epoch 102/500
# 11/11 - 0s - loss: 0.0110 - val_loss: 0.1630 - 42ms/epoch - 4ms/step
# Epoch 103/500
# 11/11 - 0s - loss: 0.0093 - val_loss: 0.1393 - 50ms/epoch - 5ms/step
# Epoch 104/500
# 11/11 - 0s - loss: 0.0094 - val_loss: 0.1366 - 40ms/epoch - 4ms/step
# Epoch 105/500
# 11/11 - 0s - loss: 0.0101 - val_loss: 0.1482 - 48ms/epoch - 4ms/step
# Epoch 106/500
# 11/11 - 0s - loss: 0.0099 - val_loss: 0.1382 - 56ms/epoch - 5ms/step
# Epoch 107/500
# 11/11 - 0s - loss: 0.0124 - val_loss: 0.1470 - 56ms/epoch - 5ms/step
# Epoch 108/500
# 11/11 - 0s - loss: 0.0094 - val_loss: 0.1525 - 49ms/epoch - 4ms/step
# Epoch 109/500
# 11/11 - 0s - loss: 0.0097 - val_loss: 0.1289 - 51ms/epoch - 5ms/step
# Epoch 110/500
# 11/11 - 0s - loss: 0.0106 - val_loss: 0.1359 - 46ms/epoch - 4ms/step
# Epoch 111/500
# 11/11 - 0s - loss: 0.0089 - val_loss: 0.1449 - 42ms/epoch - 4ms/step
# Epoch 112/500
# 11/11 - 0s - loss: 0.0091 - val_loss: 0.1360 - 49ms/epoch - 4ms/step
# Epoch 113/500
# 11/11 - 0s - loss: 0.0096 - val_loss: 0.1434 - 49ms/epoch - 4ms/step
# Epoch 114/500
# 11/11 - 0s - loss: 0.0089 - val_loss: 0.1511 - 56ms/epoch - 5ms/step
# Epoch 115/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1297 - 51ms/epoch - 5ms/step
# Epoch 116/500
# 11/11 - 0s - loss: 0.0102 - val_loss: 0.1358 - 55ms/epoch - 5ms/step
# Epoch 117/500
# 11/11 - 0s - loss: 0.0090 - val_loss: 0.1464 - 54ms/epoch - 5ms/step
# Epoch 118/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1342 - 49ms/epoch - 4ms/step
# Epoch 119/500
# 11/11 - 0s - loss: 0.0095 - val_loss: 0.1458 - 51ms/epoch - 5ms/step
# Epoch 120/500
# 11/11 - 0s - loss: 0.0081 - val_loss: 0.1513 - 55ms/epoch - 5ms/step
# Epoch 121/500
# 11/11 - 0s - loss: 0.0084 - val_loss: 0.1313 - 54ms/epoch - 5ms/step
# Epoch 122/500
# 11/11 - 0s - loss: 0.0088 - val_loss: 0.1354 - 41ms/epoch - 4ms/step
# Epoch 123/500
# 11/11 - 0s - loss: 0.0084 - val_loss: 0.1473 - 50ms/epoch - 5ms/step
# Epoch 124/500
# 11/11 - 0s - loss: 0.0085 - val_loss: 0.1361 - 51ms/epoch - 5ms/step
# Epoch 125/500
# 11/11 - 0s - loss: 0.0088 - val_loss: 0.1472 - 49ms/epoch - 4ms/step
# Epoch 126/500
# 11/11 - 0s - loss: 0.0079 - val_loss: 0.1591 - 55ms/epoch - 5ms/step
# Epoch 127/500
# 11/11 - 0s - loss: 0.0081 - val_loss: 0.1301 - 55ms/epoch - 5ms/step
# Epoch 128/500
# 11/11 - 0s - loss: 0.0087 - val_loss: 0.1339 - 47ms/epoch - 4ms/step
# Epoch 129/500
# 11/11 - 0s - loss: 0.0081 - val_loss: 0.1524 - 44ms/epoch - 4ms/step
# Epoch 130/500
# 11/11 - 0s - loss: 0.0082 - val_loss: 0.1376 - 55ms/epoch - 5ms/step
# Epoch 131/500
# 11/11 - 0s - loss: 0.0087 - val_loss: 0.1481 - 43ms/epoch - 4ms/step
# Epoch 132/500
# 11/11 - 0s - loss: 0.0076 - val_loss: 0.1633 - 48ms/epoch - 4ms/step
# Epoch 133/500
# 11/11 - 0s - loss: 0.0079 - val_loss: 0.1304 - 55ms/epoch - 5ms/step
# Epoch 134/500
# 11/11 - 0s - loss: 0.0088 - val_loss: 0.1305 - 56ms/epoch - 5ms/step
# Epoch 135/500
# 11/11 - 0s - loss: 0.0083 - val_loss: 0.1811 - 56ms/epoch - 5ms/step
# Epoch 136/500
# 11/11 - 0s - loss: 0.0091 - val_loss: 0.1329 - 56ms/epoch - 5ms/step
# Epoch 137/500
# 11/11 - 0s - loss: 0.0106 - val_loss: 0.1263 - 48ms/epoch - 4ms/step
# Epoch 138/500
# 11/11 - 0s - loss: 0.0096 - val_loss: 0.1457 - 49ms/epoch - 4ms/step
# Epoch 139/500
# 11/11 - 0s - loss: 0.0093 - val_loss: 0.1294 - 40ms/epoch - 4ms/step
# Epoch 140/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1435 - 58ms/epoch - 5ms/step
# Epoch 141/500
# 11/11 - 0s - loss: 0.0076 - val_loss: 0.1307 - 40ms/epoch - 4ms/step
# Epoch 142/500
# 11/11 - 0s - loss: 0.0078 - val_loss: 0.1289 - 50ms/epoch - 5ms/step
# Epoch 143/500
# 11/11 - 0s - loss: 0.0079 - val_loss: 0.1363 - 49ms/epoch - 4ms/step
# Epoch 144/500
# 11/11 - 0s - loss: 0.0074 - val_loss: 0.1381 - 55ms/epoch - 5ms/step
# Epoch 145/500
# 11/11 - 0s - loss: 0.0073 - val_loss: 0.1289 - 48ms/epoch - 4ms/step
# Epoch 146/500
# 11/11 - 0s - loss: 0.0077 - val_loss: 0.1461 - 48ms/epoch - 4ms/step
# Epoch 147/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.1418 - 42ms/epoch - 4ms/step
# Epoch 148/500
# 11/11 - 0s - loss: 0.0069 - val_loss: 0.1309 - 49ms/epoch - 4ms/step
# Epoch 149/500
# 11/11 - 0s - loss: 0.0071 - val_loss: 0.1478 - 42ms/epoch - 4ms/step
# Epoch 150/500
# 11/11 - 0s - loss: 0.0069 - val_loss: 0.1391 - 48ms/epoch - 4ms/step
# Epoch 151/500
# 11/11 - 0s - loss: 0.0067 - val_loss: 0.1335 - 50ms/epoch - 5ms/step
# Epoch 152/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.1531 - 47ms/epoch - 4ms/step
# Epoch 153/500
# 11/11 - 0s - loss: 0.0069 - val_loss: 0.1374 - 54ms/epoch - 5ms/step
# Epoch 154/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.1302 - 43ms/epoch - 4ms/step
# Epoch 155/500
# 11/11 - 0s - loss: 0.0072 - val_loss: 0.1506 - 56ms/epoch - 5ms/step
# Epoch 156/500
# 11/11 - 0s - loss: 0.0072 - val_loss: 0.1345 - 41ms/epoch - 4ms/step
# Epoch 157/500
# 11/11 - 0s - loss: 0.0081 - val_loss: 0.1377 - 48ms/epoch - 4ms/step
# Epoch 158/500
# 11/11 - 0s - loss: 0.0079 - val_loss: 0.1487 - 56ms/epoch - 5ms/step
# Epoch 159/500
# 11/11 - 0s - loss: 0.0077 - val_loss: 0.1217 - 41ms/epoch - 4ms/step
# Epoch 160/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1462 - 50ms/epoch - 5ms/step
# Epoch 161/500
# 11/11 - 0s - loss: 0.0072 - val_loss: 0.1383 - 40ms/epoch - 4ms/step
# Epoch 162/500
# 11/11 - 0s - loss: 0.0071 - val_loss: 0.1256 - 55ms/epoch - 5ms/step
# Epoch 163/500
# 11/11 - 0s - loss: 0.0079 - val_loss: 0.1413 - 49ms/epoch - 4ms/step
# Epoch 164/500
# 11/11 - 0s - loss: 0.0069 - val_loss: 0.1324 - 42ms/epoch - 4ms/step
# Epoch 165/500
# 11/11 - 0s - loss: 0.0067 - val_loss: 0.1286 - 46ms/epoch - 4ms/step
# Epoch 166/500
# 11/11 - 0s - loss: 0.0073 - val_loss: 0.1433 - 50ms/epoch - 5ms/step
# Epoch 167/500
# 11/11 - 0s - loss: 0.0067 - val_loss: 0.1282 - 40ms/epoch - 4ms/step
# Epoch 168/500
# 11/11 - 0s - loss: 0.0067 - val_loss: 0.1267 - 42ms/epoch - 4ms/step
# Epoch 169/500
# 11/11 - 0s - loss: 0.0073 - val_loss: 0.1420 - 41ms/epoch - 4ms/step
# Epoch 170/500
# 11/11 - 0s - loss: 0.0076 - val_loss: 0.1273 - 56ms/epoch - 5ms/step
# Epoch 171/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1278 - 49ms/epoch - 4ms/step
# Epoch 172/500
# 11/11 - 0s - loss: 0.0083 - val_loss: 0.1502 - 49ms/epoch - 4ms/step
# Epoch 173/500
# 11/11 - 0s - loss: 0.0092 - val_loss: 0.1105 - 39ms/epoch - 4ms/step
# Epoch 174/500
# 11/11 - 0s - loss: 0.0110 - val_loss: 0.1069 - 50ms/epoch - 5ms/step
# Epoch 175/500
# 11/11 - 0s - loss: 0.0085 - val_loss: 0.1381 - 41ms/epoch - 4ms/step
# Epoch 176/500
# 11/11 - 0s - loss: 0.0090 - val_loss: 0.1175 - 60ms/epoch - 5ms/step
# Epoch 177/500
# 11/11 - 0s - loss: 0.0096 - val_loss: 0.1267 - 46ms/epoch - 4ms/step
# Epoch 178/500
# 11/11 - 0s - loss: 0.0077 - val_loss: 0.1405 - 53ms/epoch - 5ms/step
# Epoch 179/500
# 11/11 - 0s - loss: 0.0093 - val_loss: 0.1106 - 37ms/epoch - 3ms/step
# Epoch 180/500
# 11/11 - 0s - loss: 0.0103 - val_loss: 0.0939 - 49ms/epoch - 4ms/step
# Epoch 181/500
# 11/11 - 0s - loss: 0.0102 - val_loss: 0.1431 - 49ms/epoch - 4ms/step
# Epoch 182/500
# 11/11 - 0s - loss: 0.0088 - val_loss: 0.1121 - 49ms/epoch - 4ms/step
# Epoch 183/500
# 11/11 - 0s - loss: 0.0083 - val_loss: 0.1355 - 55ms/epoch - 5ms/step
# Epoch 184/500
# 11/11 - 0s - loss: 0.0061 - val_loss: 0.1227 - 56ms/epoch - 5ms/step
# Epoch 185/500
# 11/11 - 0s - loss: 0.0063 - val_loss: 0.1180 - 40ms/epoch - 4ms/step
# Epoch 186/500
# 11/11 - 0s - loss: 0.0060 - val_loss: 0.1269 - 58ms/epoch - 5ms/step
# Epoch 187/500
# 11/11 - 0s - loss: 0.0060 - val_loss: 0.1357 - 33ms/epoch - 3ms/step
# Epoch 188/500
# 11/11 - 0s - loss: 0.0058 - val_loss: 0.1270 - 33ms/epoch - 3ms/step
# Epoch 189/500
# 11/11 - 0s - loss: 0.0058 - val_loss: 0.1324 - 33ms/epoch - 3ms/step
# Epoch 190/500
# 11/11 - 0s - loss: 0.0057 - val_loss: 0.1294 - 42ms/epoch - 4ms/step
# Epoch 191/500
# 11/11 - 0s - loss: 0.0056 - val_loss: 0.1269 - 43ms/epoch - 4ms/step
# Epoch 192/500
# 11/11 - 0s - loss: 0.0057 - val_loss: 0.1324 - 40ms/epoch - 4ms/step
# Epoch 193/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1273 - 34ms/epoch - 3ms/step
# Epoch 194/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1281 - 56ms/epoch - 5ms/step
# Epoch 195/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1316 - 42ms/epoch - 4ms/step
# Epoch 196/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1269 - 46ms/epoch - 4ms/step
# Epoch 197/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1296 - 50ms/epoch - 5ms/step
# Epoch 198/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1306 - 51ms/epoch - 5ms/step
# Epoch 199/500
# 11/11 - 0s - loss: 0.0054 - val_loss: 0.1263 - 39ms/epoch - 4ms/step
# Epoch 200/500
# 11/11 - 0s - loss: 0.0056 - val_loss: 0.1317 - 59ms/epoch - 5ms/step
# Epoch 201/500
# 11/11 - 0s - loss: 0.0056 - val_loss: 0.1280 - 45ms/epoch - 4ms/step
# Epoch 202/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1237 - 41ms/epoch - 4ms/step
# Epoch 203/500
# 11/11 - 0s - loss: 0.0058 - val_loss: 0.1341 - 56ms/epoch - 5ms/step
# Epoch 204/500
# 11/11 - 0s - loss: 0.0060 - val_loss: 0.1238 - 41ms/epoch - 4ms/step
# Epoch 205/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.1223 - 56ms/epoch - 5ms/step
# Epoch 206/500
# 11/11 - 0s - loss: 0.0071 - val_loss: 0.1277 - 48ms/epoch - 4ms/step
# Epoch 207/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.1152 - 49ms/epoch - 4ms/step
# Epoch 208/500
# 11/11 - 0s - loss: 0.0091 - val_loss: 0.1291 - 41ms/epoch - 4ms/step
# Epoch 209/500
# 11/11 - 0s - loss: 0.0065 - val_loss: 0.1199 - 49ms/epoch - 4ms/step
# Epoch 210/500
# 11/11 - 0s - loss: 0.0065 - val_loss: 0.1106 - 49ms/epoch - 4ms/step
# Epoch 211/500
# 11/11 - 0s - loss: 0.0076 - val_loss: 0.1281 - 49ms/epoch - 4ms/step
# Epoch 212/500
# 11/11 - 0s - loss: 0.0062 - val_loss: 0.1219 - 41ms/epoch - 4ms/step
# Epoch 213/500
# 11/11 - 0s - loss: 0.0063 - val_loss: 0.1124 - 48ms/epoch - 4ms/step
# Epoch 214/500
# 11/11 - 0s - loss: 0.0075 - val_loss: 0.1231 - 50ms/epoch - 5ms/step
# Epoch 215/500
# 11/11 - 0s - loss: 0.0062 - val_loss: 0.1176 - 47ms/epoch - 4ms/step
# Epoch 216/500
# 11/11 - 0s - loss: 0.0063 - val_loss: 0.1125 - 58ms/epoch - 5ms/step
# Epoch 217/500
# 11/11 - 0s - loss: 0.0072 - val_loss: 0.1238 - 39ms/epoch - 4ms/step
# Epoch 218/500
# 11/11 - 0s - loss: 0.0059 - val_loss: 0.1143 - 49ms/epoch - 4ms/step
# Epoch 219/500
# 11/11 - 0s - loss: 0.0057 - val_loss: 0.1117 - 56ms/epoch - 5ms/step
# Epoch 220/500
# 11/11 - 0s - loss: 0.0065 - val_loss: 0.1270 - 42ms/epoch - 4ms/step
# Epoch 221/500
# 11/11 - 0s - loss: 0.0056 - val_loss: 0.1142 - 47ms/epoch - 4ms/step
# Epoch 222/500
# 11/11 - 0s - loss: 0.0054 - val_loss: 0.1131 - 57ms/epoch - 5ms/step
# Epoch 223/500
# 11/11 - 0s - loss: 0.0059 - val_loss: 0.1269 - 48ms/epoch - 4ms/step
# Epoch 224/500
# 11/11 - 0s - loss: 0.0058 - val_loss: 0.1140 - 51ms/epoch - 5ms/step
# Epoch 225/500
# 11/11 - 0s - loss: 0.0062 - val_loss: 0.1115 - 37ms/epoch - 3ms/step
# Epoch 226/500
# 11/11 - 0s - loss: 0.0065 - val_loss: 0.1259 - 57ms/epoch - 5ms/step
# Epoch 227/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.1085 - 41ms/epoch - 4ms/step
# Epoch 228/500
# 11/11 - 0s - loss: 0.0097 - val_loss: 0.1120 - 56ms/epoch - 5ms/step
# Epoch 229/500
# 11/11 - 0s - loss: 0.0072 - val_loss: 0.1383 - 48ms/epoch - 4ms/step
# Epoch 230/500
# 11/11 - 0s - loss: 0.0096 - val_loss: 0.0970 - 43ms/epoch - 4ms/step
# Epoch 231/500
# 11/11 - 0s - loss: 0.0124 - val_loss: 0.0739 - 48ms/epoch - 4ms/step
# Epoch 232/500
# 11/11 - 0s - loss: 0.0112 - val_loss: 0.1514 - 53ms/epoch - 5ms/step
# Epoch 233/500
# 11/11 - 0s - loss: 0.0113 - val_loss: 0.0839 - 45ms/epoch - 4ms/step
# Epoch 234/500
# 11/11 - 0s - loss: 0.0110 - val_loss: 0.0858 - 55ms/epoch - 5ms/step
# Epoch 235/500
# 11/11 - 0s - loss: 0.0102 - val_loss: 0.1317 - 49ms/epoch - 4ms/step
# Epoch 236/500
# 11/11 - 0s - loss: 0.0088 - val_loss: 0.0783 - 51ms/epoch - 5ms/step
# Epoch 237/500
# 11/11 - 0s - loss: 0.0069 - val_loss: 0.1158 - 38ms/epoch - 3ms/step
# Epoch 238/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1150 - 62ms/epoch - 6ms/step
# Epoch 239/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1028 - 35ms/epoch - 3ms/step
# Epoch 240/500
# 11/11 - 0s - loss: 0.0052 - val_loss: 0.1148 - 50ms/epoch - 5ms/step
# Epoch 241/500
# 11/11 - 0s - loss: 0.0050 - val_loss: 0.1207 - 49ms/epoch - 4ms/step
# Epoch 242/500
# 11/11 - 0s - loss: 0.0050 - val_loss: 0.1123 - 55ms/epoch - 5ms/step
# Epoch 243/500
# 11/11 - 0s - loss: 0.0049 - val_loss: 0.1176 - 42ms/epoch - 4ms/step
# Epoch 244/500
# 11/11 - 0s - loss: 0.0048 - val_loss: 0.1206 - 56ms/epoch - 5ms/step
# Epoch 245/500
# 11/11 - 0s - loss: 0.0048 - val_loss: 0.1153 - 40ms/epoch - 4ms/step
# Epoch 246/500
# 11/11 - 0s - loss: 0.0048 - val_loss: 0.1180 - 56ms/epoch - 5ms/step
# Epoch 247/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1202 - 50ms/epoch - 5ms/step
# Epoch 248/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1151 - 56ms/epoch - 5ms/step
# Epoch 249/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1180 - 48ms/epoch - 4ms/step
# Epoch 250/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1201 - 40ms/epoch - 4ms/step
# Epoch 251/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1140 - 59ms/epoch - 5ms/step
# Epoch 252/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1186 - 49ms/epoch - 4ms/step
# Epoch 253/500
# 11/11 - 0s - loss: 0.0046 - val_loss: 0.1209 - 40ms/epoch - 4ms/step
# Epoch 254/500
# 11/11 - 0s - loss: 0.0046 - val_loss: 0.1125 - 57ms/epoch - 5ms/step
# Epoch 255/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1199 - 49ms/epoch - 4ms/step
# Epoch 256/500
# 11/11 - 0s - loss: 0.0046 - val_loss: 0.1214 - 52ms/epoch - 5ms/step
# Epoch 257/500
# 11/11 - 0s - loss: 0.0046 - val_loss: 0.1093 - 42ms/epoch - 4ms/step
# Epoch 258/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1221 - 41ms/epoch - 4ms/step
# Epoch 259/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1214 - 57ms/epoch - 5ms/step
# Epoch 260/500
# 11/11 - 0s - loss: 0.0048 - val_loss: 0.1039 - 40ms/epoch - 4ms/step
# Epoch 261/500
# 11/11 - 0s - loss: 0.0049 - val_loss: 0.1272 - 51ms/epoch - 5ms/step
# Epoch 262/500
# 11/11 - 0s - loss: 0.0051 - val_loss: 0.1207 - 48ms/epoch - 4ms/step
# Epoch 263/500
# 11/11 - 0s - loss: 0.0054 - val_loss: 0.0938 - 56ms/epoch - 5ms/step
# Epoch 264/500
# 11/11 - 0s - loss: 0.0057 - val_loss: 0.1365 - 41ms/epoch - 4ms/step
# Epoch 265/500
# 11/11 - 0s - loss: 0.0064 - val_loss: 0.1151 - 47ms/epoch - 4ms/step
# Epoch 266/500
# 11/11 - 0s - loss: 0.0081 - val_loss: 0.0772 - 49ms/epoch - 4ms/step
# Epoch 267/500
# 11/11 - 0s - loss: 0.0082 - val_loss: 0.1471 - 57ms/epoch - 5ms/step
# Epoch 268/500
# 11/11 - 0s - loss: 0.0101 - val_loss: 0.0982 - 43ms/epoch - 4ms/step
# Epoch 269/500
# 11/11 - 0s - loss: 0.0134 - val_loss: 0.0699 - 40ms/epoch - 4ms/step
# Epoch 270/500
# 11/11 - 0s - loss: 0.0124 - val_loss: 0.1242 - 39ms/epoch - 4ms/step
# Epoch 271/500
# 11/11 - 0s - loss: 0.0123 - val_loss: 0.0673 - 51ms/epoch - 5ms/step
# Epoch 272/500
# 11/11 - 0s - loss: 0.0099 - val_loss: 0.0999 - 55ms/epoch - 5ms/step
# Epoch 273/500
# 11/11 - 0s - loss: 0.0071 - val_loss: 0.0994 - 48ms/epoch - 4ms/step
# Epoch 274/500
# 11/11 - 0s - loss: 0.0062 - val_loss: 0.0777 - 41ms/epoch - 4ms/step
# Epoch 275/500
# 11/11 - 0s - loss: 0.0049 - val_loss: 0.1086 - 50ms/epoch - 5ms/step
# Epoch 276/500
# 11/11 - 0s - loss: 0.0045 - val_loss: 0.1025 - 58ms/epoch - 5ms/step
# Epoch 277/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.1059 - 43ms/epoch - 4ms/step
# Epoch 278/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.1078 - 40ms/epoch - 4ms/step
# Epoch 279/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.1091 - 41ms/epoch - 4ms/step
# Epoch 280/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1096 - 42ms/epoch - 4ms/step
# Epoch 281/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1096 - 51ms/epoch - 5ms/step
# Epoch 282/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1089 - 46ms/epoch - 4ms/step
# Epoch 283/500
# 11/11 - 0s - loss: 0.0042 - val_loss: 0.1097 - 41ms/epoch - 4ms/step
# Epoch 284/500
# 11/11 - 0s - loss: 0.0042 - val_loss: 0.1085 - 49ms/epoch - 4ms/step
# Epoch 285/500
# 11/11 - 0s - loss: 0.0042 - val_loss: 0.1083 - 48ms/epoch - 4ms/step
# Epoch 286/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.1091 - 56ms/epoch - 5ms/step
# Epoch 287/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.1078 - 42ms/epoch - 4ms/step
# Epoch 288/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1072 - 48ms/epoch - 4ms/step
# Epoch 289/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1080 - 49ms/epoch - 4ms/step
# Epoch 290/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1053 - 42ms/epoch - 4ms/step
# Epoch 291/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1060 - 48ms/epoch - 4ms/step
# Epoch 292/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1074 - 49ms/epoch - 4ms/step
# Epoch 293/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1031 - 55ms/epoch - 5ms/step
# Epoch 294/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1049 - 43ms/epoch - 4ms/step
# Epoch 295/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1066 - 54ms/epoch - 5ms/step
# Epoch 296/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.0998 - 34ms/epoch - 3ms/step
# Epoch 297/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1047 - 50ms/epoch - 5ms/step
# Epoch 298/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1068 - 49ms/epoch - 4ms/step
# Epoch 299/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.0943 - 48ms/epoch - 4ms/step
# Epoch 300/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.1040 - 50ms/epoch - 5ms/step
# Epoch 301/500
# 11/11 - 0s - loss: 0.0046 - val_loss: 0.1094 - 48ms/epoch - 4ms/step
# Epoch 302/500
# 11/11 - 0s - loss: 0.0049 - val_loss: 0.0823 - 53ms/epoch - 5ms/step
# Epoch 303/500
# 11/11 - 0s - loss: 0.0054 - val_loss: 0.1143 - 45ms/epoch - 4ms/step
# Epoch 304/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.1065 - 56ms/epoch - 5ms/step
# Epoch 305/500
# 11/11 - 0s - loss: 0.0055 - val_loss: 0.0775 - 48ms/epoch - 4ms/step
# Epoch 306/500
# 11/11 - 0s - loss: 0.0067 - val_loss: 0.1160 - 40ms/epoch - 4ms/step
# Epoch 307/500
# 11/11 - 0s - loss: 0.0064 - val_loss: 0.0922 - 39ms/epoch - 4ms/step
# Epoch 308/500
# 11/11 - 0s - loss: 0.0070 - val_loss: 0.0713 - 54ms/epoch - 5ms/step
# Epoch 309/500
# 11/11 - 0s - loss: 0.0074 - val_loss: 0.1232 - 43ms/epoch - 4ms/step
# Epoch 310/500
# 11/11 - 0s - loss: 0.0065 - val_loss: 0.0840 - 55ms/epoch - 5ms/step
# Epoch 311/500
# 11/11 - 0s - loss: 0.0065 - val_loss: 0.0867 - 39ms/epoch - 4ms/step
# Epoch 312/500
# 11/11 - 0s - loss: 0.0057 - val_loss: 0.1068 - 57ms/epoch - 5ms/step
# Epoch 313/500
# 11/11 - 0s - loss: 0.0067 - val_loss: 0.0770 - 49ms/epoch - 4ms/step
# Epoch 314/500
# 11/11 - 0s - loss: 0.0068 - val_loss: 0.0924 - 49ms/epoch - 4ms/step
# Epoch 315/500
# 11/11 - 0s - loss: 0.0053 - val_loss: 0.1053 - 49ms/epoch - 4ms/step
# Epoch 316/500
# 11/11 - 0s - loss: 0.0056 - val_loss: 0.0835 - 42ms/epoch - 4ms/step
# Epoch 317/500
# 11/11 - 0s - loss: 0.0050 - val_loss: 0.1007 - 55ms/epoch - 5ms/step
# Epoch 318/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.0996 - 41ms/epoch - 4ms/step
# Epoch 319/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.0879 - 49ms/epoch - 4ms/step
# Epoch 320/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0994 - 48ms/epoch - 4ms/step
# Epoch 321/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.1015 - 49ms/epoch - 4ms/step
# Epoch 322/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.0899 - 48ms/epoch - 4ms/step
# Epoch 323/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.0988 - 48ms/epoch - 4ms/step
# Epoch 324/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.1025 - 49ms/epoch - 4ms/step
# Epoch 325/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0921 - 41ms/epoch - 4ms/step
# Epoch 326/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0980 - 41ms/epoch - 4ms/step
# Epoch 327/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1020 - 42ms/epoch - 4ms/step
# Epoch 328/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0922 - 47ms/epoch - 4ms/step
# Epoch 329/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0980 - 49ms/epoch - 4ms/step
# Epoch 330/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1026 - 61ms/epoch - 6ms/step
# Epoch 331/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0919 - 50ms/epoch - 5ms/step
# Epoch 332/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0979 - 53ms/epoch - 5ms/step
# Epoch 333/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1024 - 49ms/epoch - 4ms/step
# Epoch 334/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0910 - 46ms/epoch - 4ms/step
# Epoch 335/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.0977 - 51ms/epoch - 5ms/step
# Epoch 336/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.1039 - 55ms/epoch - 5ms/step
# Epoch 337/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.0897 - 41ms/epoch - 4ms/step
# Epoch 338/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0970 - 49ms/epoch - 4ms/step
# Epoch 339/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.1047 - 49ms/epoch - 4ms/step
# Epoch 340/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0884 - 60ms/epoch - 5ms/step
# Epoch 341/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.0971 - 49ms/epoch - 4ms/step
# Epoch 342/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.1060 - 49ms/epoch - 4ms/step
# Epoch 343/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.0869 - 55ms/epoch - 5ms/step
# Epoch 344/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.0966 - 54ms/epoch - 5ms/step
# Epoch 345/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1056 - 53ms/epoch - 5ms/step
# Epoch 346/500
# 11/11 - 0s - loss: 0.0049 - val_loss: 0.0835 - 48ms/epoch - 4ms/step
# Epoch 347/500
# 11/11 - 0s - loss: 0.0051 - val_loss: 0.0946 - 44ms/epoch - 4ms/step
# Epoch 348/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1073 - 56ms/epoch - 5ms/step
# Epoch 349/500
# 11/11 - 0s - loss: 0.0052 - val_loss: 0.0848 - 49ms/epoch - 4ms/step
# Epoch 350/500
# 11/11 - 0s - loss: 0.0052 - val_loss: 0.0918 - 41ms/epoch - 4ms/step
# Epoch 351/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.1097 - 57ms/epoch - 5ms/step
# Epoch 352/500
# 11/11 - 0s - loss: 0.0054 - val_loss: 0.0814 - 39ms/epoch - 4ms/step
# Epoch 353/500
# 11/11 - 0s - loss: 0.0051 - val_loss: 0.0948 - 47ms/epoch - 4ms/step
# Epoch 354/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1066 - 43ms/epoch - 4ms/step
# Epoch 355/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.0835 - 56ms/epoch - 5ms/step
# Epoch 356/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.0989 - 39ms/epoch - 4ms/step
# Epoch 357/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.1051 - 51ms/epoch - 5ms/step
# Epoch 358/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0864 - 55ms/epoch - 5ms/step
# Epoch 359/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.0989 - 42ms/epoch - 4ms/step
# Epoch 360/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1051 - 41ms/epoch - 4ms/step
# Epoch 361/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0888 - 56ms/epoch - 5ms/step
# Epoch 362/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.0996 - 51ms/epoch - 5ms/step
# Epoch 363/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1055 - 42ms/epoch - 4ms/step
# Epoch 364/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.0907 - 52ms/epoch - 5ms/step
# Epoch 365/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1001 - 44ms/epoch - 4ms/step
# Epoch 366/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1064 - 43ms/epoch - 4ms/step
# Epoch 367/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0920 - 58ms/epoch - 5ms/step
# Epoch 368/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1003 - 49ms/epoch - 4ms/step
# Epoch 369/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1074 - 42ms/epoch - 4ms/step
# Epoch 370/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.0920 - 46ms/epoch - 4ms/step
# Epoch 371/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1002 - 42ms/epoch - 4ms/step
# Epoch 372/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1087 - 59ms/epoch - 5ms/step
# Epoch 373/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0916 - 50ms/epoch - 5ms/step
# Epoch 374/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0991 - 57ms/epoch - 5ms/step
# Epoch 375/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.1103 - 55ms/epoch - 5ms/step
# Epoch 376/500
# 11/11 - 0s - loss: 0.0042 - val_loss: 0.0908 - 46ms/epoch - 4ms/step
# Epoch 377/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.0929 - 58ms/epoch - 5ms/step
# Epoch 378/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1146 - 42ms/epoch - 4ms/step
# Epoch 379/500
# 11/11 - 0s - loss: 0.0053 - val_loss: 0.0837 - 56ms/epoch - 5ms/step
# Epoch 380/500
# 11/11 - 0s - loss: 0.0052 - val_loss: 0.0933 - 41ms/epoch - 4ms/step
# Epoch 381/500
# 11/11 - 0s - loss: 0.0048 - val_loss: 0.1143 - 49ms/epoch - 4ms/step
# Epoch 382/500
# 11/11 - 0s - loss: 0.0054 - val_loss: 0.0816 - 55ms/epoch - 5ms/step
# Epoch 383/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.0996 - 43ms/epoch - 4ms/step
# Epoch 384/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1099 - 51ms/epoch - 5ms/step
# Epoch 385/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.0862 - 56ms/epoch - 5ms/step
# Epoch 386/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.1034 - 49ms/epoch - 4ms/step
# Epoch 387/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1065 - 50ms/epoch - 5ms/step
# Epoch 388/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0888 - 41ms/epoch - 4ms/step
# Epoch 389/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1041 - 58ms/epoch - 5ms/step
# Epoch 390/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1079 - 42ms/epoch - 4ms/step
# Epoch 391/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0920 - 48ms/epoch - 4ms/step
# Epoch 392/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1039 - 50ms/epoch - 5ms/step
# Epoch 393/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1077 - 55ms/epoch - 5ms/step
# Epoch 394/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.0931 - 40ms/epoch - 4ms/step
# Epoch 395/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1042 - 54ms/epoch - 5ms/step
# Epoch 396/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1087 - 43ms/epoch - 4ms/step
# Epoch 397/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.0933 - 49ms/epoch - 4ms/step
# Epoch 398/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1044 - 38ms/epoch - 3ms/step
# Epoch 399/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1105 - 62ms/epoch - 6ms/step
# Epoch 400/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0920 - 37ms/epoch - 3ms/step
# Epoch 401/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1035 - 49ms/epoch - 4ms/step
# Epoch 402/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1117 - 49ms/epoch - 4ms/step
# Epoch 403/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0892 - 48ms/epoch - 4ms/step
# Epoch 404/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1026 - 49ms/epoch - 4ms/step
# Epoch 405/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.1146 - 56ms/epoch - 5ms/step
# Epoch 406/500
# 11/11 - 0s - loss: 0.0046 - val_loss: 0.0872 - 43ms/epoch - 4ms/step
# Epoch 407/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.1011 - 48ms/epoch - 4ms/step
# Epoch 408/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1159 - 49ms/epoch - 4ms/step
# Epoch 409/500
# 11/11 - 0s - loss: 0.0047 - val_loss: 0.0861 - 48ms/epoch - 4ms/step
# Epoch 410/500
# 11/11 - 0s - loss: 0.0042 - val_loss: 0.1024 - 57ms/epoch - 5ms/step
# Epoch 411/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1153 - 48ms/epoch - 4ms/step
# Epoch 412/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.0876 - 42ms/epoch - 4ms/step
# Epoch 413/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.1046 - 48ms/epoch - 4ms/step
# Epoch 414/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1136 - 49ms/epoch - 4ms/step
# Epoch 415/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.0905 - 55ms/epoch - 5ms/step
# Epoch 416/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1061 - 50ms/epoch - 5ms/step
# Epoch 417/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1124 - 46ms/epoch - 4ms/step
# Epoch 418/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0919 - 40ms/epoch - 4ms/step
# Epoch 419/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1081 - 43ms/epoch - 4ms/step
# Epoch 420/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1122 - 48ms/epoch - 4ms/step
# Epoch 421/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.0953 - 56ms/epoch - 5ms/step
# Epoch 422/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1086 - 44ms/epoch - 4ms/step
# Epoch 423/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1112 - 42ms/epoch - 4ms/step
# Epoch 424/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.0960 - 48ms/epoch - 4ms/step
# Epoch 425/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1100 - 41ms/epoch - 4ms/step
# Epoch 426/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1117 - 57ms/epoch - 5ms/step
# Epoch 427/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.0958 - 41ms/epoch - 4ms/step
# Epoch 428/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1108 - 56ms/epoch - 5ms/step
# Epoch 429/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1123 - 49ms/epoch - 4ms/step
# Epoch 430/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0960 - 50ms/epoch - 5ms/step
# Epoch 431/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1106 - 48ms/epoch - 4ms/step
# Epoch 432/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1138 - 40ms/epoch - 4ms/step
# Epoch 433/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.0931 - 57ms/epoch - 5ms/step
# Epoch 434/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.1104 - 42ms/epoch - 4ms/step
# Epoch 435/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1157 - 48ms/epoch - 4ms/step
# Epoch 436/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0924 - 56ms/epoch - 5ms/step
# Epoch 437/500
# 11/11 - 0s - loss: 0.0039 - val_loss: 0.1090 - 41ms/epoch - 4ms/step
# Epoch 438/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1171 - 49ms/epoch - 4ms/step
# Epoch 439/500
# 11/11 - 0s - loss: 0.0044 - val_loss: 0.0904 - 48ms/epoch - 4ms/step
# Epoch 440/500
# 11/11 - 0s - loss: 0.0040 - val_loss: 0.1083 - 49ms/epoch - 4ms/step
# Epoch 441/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.1180 - 60ms/epoch - 5ms/step
# Epoch 442/500
# 11/11 - 0s - loss: 0.0043 - val_loss: 0.0907 - 44ms/epoch - 4ms/step
# Epoch 443/500
# 11/11 - 0s - loss: 0.0038 - val_loss: 0.1085 - 55ms/epoch - 5ms/step
# Epoch 444/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1171 - 33ms/epoch - 3ms/step
# Epoch 445/500
# 11/11 - 0s - loss: 0.0041 - val_loss: 0.0910 - 42ms/epoch - 4ms/step
# Epoch 446/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.1100 - 40ms/epoch - 4ms/step
# Epoch 447/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1172 - 42ms/epoch - 4ms/step
# Epoch 448/500
# 11/11 - 0s - loss: 0.0037 - val_loss: 0.0940 - 48ms/epoch - 4ms/step
# Epoch 449/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1112 - 56ms/epoch - 5ms/step
# Epoch 450/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1176 - 46ms/epoch - 4ms/step
# Epoch 451/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0967 - 32ms/epoch - 3ms/step
# Epoch 452/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1124 - 60ms/epoch - 5ms/step
# Epoch 453/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1171 - 44ms/epoch - 4ms/step
# Epoch 454/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.0983 - 41ms/epoch - 4ms/step
# Epoch 455/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1133 - 54ms/epoch - 5ms/step
# Epoch 456/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1167 - 45ms/epoch - 4ms/step
# Epoch 457/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.0979 - 45ms/epoch - 4ms/step
# Epoch 458/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1142 - 40ms/epoch - 4ms/step
# Epoch 459/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1171 - 58ms/epoch - 5ms/step
# Epoch 460/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0982 - 49ms/epoch - 4ms/step
# Epoch 461/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1149 - 49ms/epoch - 4ms/step
# Epoch 462/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1178 - 51ms/epoch - 5ms/step
# Epoch 463/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0988 - 45ms/epoch - 4ms/step
# Epoch 464/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1152 - 48ms/epoch - 4ms/step
# Epoch 465/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1179 - 40ms/epoch - 4ms/step
# Epoch 466/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.0984 - 49ms/epoch - 4ms/step
# Epoch 467/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1154 - 48ms/epoch - 4ms/step
# Epoch 468/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1180 - 41ms/epoch - 4ms/step
# Epoch 469/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.0989 - 49ms/epoch - 4ms/step
# Epoch 470/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1161 - 49ms/epoch - 4ms/step
# Epoch 471/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1187 - 55ms/epoch - 5ms/step
# Epoch 472/500
# 11/11 - 0s - loss: 0.0035 - val_loss: 0.0986 - 42ms/epoch - 4ms/step
# Epoch 473/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1163 - 54ms/epoch - 5ms/step
# Epoch 474/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1184 - 46ms/epoch - 4ms/step
# Epoch 475/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0987 - 48ms/epoch - 4ms/step
# Epoch 476/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1173 - 43ms/epoch - 4ms/step
# Epoch 477/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1190 - 49ms/epoch - 4ms/step
# Epoch 478/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0988 - 49ms/epoch - 4ms/step
# Epoch 479/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1172 - 49ms/epoch - 4ms/step
# Epoch 480/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1186 - 40ms/epoch - 4ms/step
# Epoch 481/500
# 11/11 - 0s - loss: 0.0036 - val_loss: 0.0992 - 64ms/epoch - 6ms/step
# Epoch 482/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1183 - 42ms/epoch - 4ms/step
# Epoch 483/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1193 - 55ms/epoch - 5ms/step
# Epoch 484/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1002 - 56ms/epoch - 5ms/step
# Epoch 485/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1183 - 42ms/epoch - 4ms/step
# Epoch 486/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1188 - 50ms/epoch - 5ms/step
# Epoch 487/500
# 11/11 - 0s - loss: 0.0034 - val_loss: 0.1010 - 54ms/epoch - 5ms/step
# Epoch 488/500
# 11/11 - 0s - loss: 0.0032 - val_loss: 0.1191 - 33ms/epoch - 3ms/step
# Epoch 489/500
# 11/11 - 0s - loss: 0.0027 - val_loss: 0.1178 - 42ms/epoch - 4ms/step
# Epoch 490/500
# 11/11 - 0s - loss: 0.0033 - val_loss: 0.1011 - 48ms/epoch - 4ms/step
# Epoch 491/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1206 - 56ms/epoch - 5ms/step
# Epoch 492/500
# 11/11 - 0s - loss: 0.0026 - val_loss: 0.1173 - 42ms/epoch - 4ms/step
# Epoch 493/500
# 11/11 - 0s - loss: 0.0031 - val_loss: 0.1036 - 55ms/epoch - 5ms/step
# Epoch 494/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1217 - 49ms/epoch - 4ms/step
# Epoch 495/500
# 11/11 - 0s - loss: 0.0024 - val_loss: 0.1162 - 41ms/epoch - 4ms/step
# Epoch 496/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1059 - 50ms/epoch - 5ms/step
# Epoch 497/500
# 11/11 - 0s - loss: 0.0029 - val_loss: 0.1232 - 46ms/epoch - 4ms/step
# Epoch 498/500
# 11/11 - 0s - loss: 0.0024 - val_loss: 0.1146 - 54ms/epoch - 5ms/step
# Epoch 499/500
# 11/11 - 0s - loss: 0.0028 - val_loss: 0.1071 - 51ms/epoch - 5ms/step
# Epoch 500/500
# 11/11 - 0s - loss: 0.0030 - val_loss: 0.1258 - 49ms/epoch - 4ms/step

# %%
# Load the best model
best_model = load_model('CNN_LSTM.hdf5')

# %%
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], label='Training Loss')
#plt.plot(history.history['val_loss'], label='Validation Loss')
plt.yscale('log')
plt.title('CNN-LSTM Training Loss', fontsize=20)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Loss (log)',fontsize=20)
plt.legend()
plt.show()

# %%
test_predictions = best_model.predict(X_test).flatten()
# Out:
# 2/2 [==============================] - 0s 16ms/step

# %%
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})

# %%
test_predictions = best_model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
test_results.head()
# Out:
# 2/2 [==============================] - 0s 0s/step
#    Train Predictions    Actual
# 0           0.705843  0.866477
# 1           0.754727  0.849432
# 2           0.782232  0.832386
# 3           0.808459  0.815341
# 4           0.826447  0.724432

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
mae = mean_absolute_error(y_test, test_predictions)
mse = mean_squared_error(y_test, test_predictions)
mape = mean_absolute_percentage_error(y_test, test_predictions)
print('Test mae: %.5f' % mae)
print('Test mse: %.5f' % mse)
print('Test mape: %.5f' % mape)
# Out:
# Test mae: 0.09822
# Test mse: 0.01462
# Test mape: 0.13544

# %%
# 繪製預測結果與實際結果的折線圖
plt.figure(figsize=(12, 5))
plt.plot(test_df.index[time_step:], test_df['真實平均價'][time_step:], label='Actual Price')
plt.plot(test_df.index[time_step:], predictions, label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('LSTM Model - Predicted vs Actual Prices')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 7
#       4 model_cnnlstm.load_weights('CNN_LSTM.hdf5')
#       6 # Reshape X before passing it to the model
# ----> 7 y_pred_cnn_lstm = model_cnnlstm.predict(X.reshape(X.shape[0], n_past, 1))
#       9 # Initialize lists for predictions and truth
#      10 pred_cnn_lstm = []
#
# ValueError: cannot reshape array of size 1080 into shape (40,3,1)

# %%
# Get predictions on all the data
model_cnnlstm.load_weights('CNN_LSTM.hdf5')
y_pred_cnn_lstm = model_cnnlstm.predict(X.reshape(X.shape[0], history, 1))
pred_cnn_lstm = []
truth = []

for i in range(len(y_pred_cnn_lstm)):
    if i==(len(y_pred_cnn_lstm)-1):
        for j in range(len(y_pred_cnn_lstm[i])):
            pred_cnn_lstm.append(y_pred_cnn_lstm[i][j])
            truth.append(y[i][j])
    else:
        pred_cnn_lstm.append(y_pred_cnn_lstm[i][0])
        truth.append(y[i][0])


fig= plt.figure(figsize=(13,5))
plt.rcParams.update({'font.size': 18})

months = [i for i in range(len(truth))]
years= df.index
year_starts = [i for i in range(0, len(truth), 80)]
print(year_starts)
year_labels = [str(years[i].year) for i in year_starts]
print(year_labels)

plt.plot(months[0:len(y_train)], truth[0:len(y_train)],label='Train Data', lw=3)
plt.plot(months[len(y_train):], truth[len(y_train):],label='Test Data', lw=3)

plt.plot(pred_cnn_lstm,label='CNN_LSTM Predictions', lw=3, linestyle='dashed')
plt.vlines(x=len(y_train), ymin= 0, ymax = 35, lw=3, linestyle='dashed', color='r')

plt.xlabel('Year', fontsize = 20)
plt.ylabel('CO2', fontsize = 20)
plt.xticks(year_starts, year_labels)
plt.legend(fontsize = 10, loc='lower right', shadow='True')
plt.show()

# %%
y_pred = model_cnnlstm.predict(X_test)

# Plotting actual vs. predicted values
plt.figure(figsize=(10, 6))

# Plotting actual values
plt.plot(y_test, label='Actual', color='blue')

# Plotting predicted values
plt.plot(y_pred, label='Predicted', color='red')

plt.title('Actual vs. Predicted')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2/2 [==============================] - 1s 0s/step
